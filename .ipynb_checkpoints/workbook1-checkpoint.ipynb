# %% [markdown]
# # MA943 - Numerical Methods
#
# * <font color=blue> Well done. Comments and marks are in blue text throughout.</font>
# * <font color=blue> Each question is worth 15 marks and there are 10 marks for clarity and presentation.</font>
# * <font color=blue> I gave you 8/10 for clarity and presentation. Your plots and style of explanation are exemplary although there are a few points where a log axis would have been more appropriate for what you were trying to show.</font>

# %% [markdown]
# <font color=blue>
# Total mark: 15 + 15 +14 +14 + 15 + 15 + 8 = 96/100
# </font>

# %%
using PyPlot
# use for marker sizes on plots
ms = 3

# my functions
include("modules/recursion.jl");
# contains one function with the signiture 
# recursion_hom(c₁,c₂,a₁,a₂,steps,num_type="F64")
# num_type: F64, F32, Big sets Float64, Float32 or BigFloat arithmetic

# %% [markdown]
# The file 'recursion.jl' contains a single function to compute
# a homogeneous recursion of the form
# \begin{align*}
#     a_{n+1} = c_{1}a_{n} + c_{2}a_{n-1}, \enspace \text{with initial conditions } a_{1},a_{2}
# \end{align*}
#
# the function signiture is 'recursion_hom(c₁,c₂,a₁,a₂,steps,num_type="F64")'. The step controls
# the maximum step size, $n$, and the final argument controls the arithmetic type: Float64=F64, Float32=F32, BigFloat=Big.

# %% [markdown]
# ## Question 1: Precision of floating point arithmetic
#
# Consider the recursion relation
#
# $a_{n+1} = 2\, a_n - \frac{8}{9}\, a_{n-1}$
#
# with the initial conditions $a_1=1$ and $a_2=\frac{2}{3}$.
#
# 1. Calculate the first 80 terms in this sequence using single precision floating point arithmetic (Float32 in Julia). Plot the resulting sequence on a lin-log plot.
#
# 2. Repeat the calculation using double precision floating point arithmetic (Float64 in Julia) and add the results to to your plot.
#
# 3. Find the **general** solution of the recursion relation analytically (it should contain two arbitrary constants). Hint: start from the ansatz $a_n = x^n$ and find the the allowed values of $x$.
#
# 4. Find the solution that satisfies the initial conditions $a_1=1$ and $a_2=\frac{2}{3}$.
#
# 5. Find the solution that satisfies the perturbed initial conditions $a_1=1$ and $a_2=\frac{2}{3}+\epsilon$. Use the answer to explain your numerical results.
#
# 6. Julia supports arbitrary precision floating point arithmetic using the BigFloat type (see https://docs.julialang.org/en/latest/manual/integers-and-floating-point-numbers/#Arbitrary-Precision-Arithmetic-1). Try to reproduce the exact solution for the first 80 terms in the sequence using 128 bit precision and show the results on your plot.

# %% [markdown]
# ## Analytic Solutions
#
# For the analytic solution we let $\lambda^{n}=a_{n}$ so $a_{n+1}=2a_{n}-\frac{8}{9}a_{n-1}$ with $a_{1}=1,a_{2}=\frac{2}{3}$ implies
#
# \begin{align*}
#     \lambda^{n+1} &= 2\lambda^{n}-\frac{8}{9}\lambda^{n-1} \Rightarrow \lambda^{2}-2\lambda +\frac{8}{9} = 0
#     \Rightarrow \lambda_{1,2} = \frac{2\pm\sqrt{4-4\frac{8}{9}}}{2} = 1\pm\frac{1}{3}
# \end{align*}
#
# so the general solution is
#
# \begin{align*}
#     a_{n} = c_{1}\biggl(\frac{4}{3}\biggr)+c_{2}\biggl(\frac{2}{3}\biggr)
# \end{align*}
#
# Applying the constraints $a_{1}=1,a_{2}=\frac{2}{3}$ we find
#
# \begin{align*}
#     4c_{1}+2c_{2} &= 3 \\
#     16c_{1}+4c_{2} &= 6 \\
#    \Rightarrow 8c_{1} &=0 \Rightarrow c_{2} = \frac{3}{2}
# \end{align*}
#
# hence we have the solution
#
# \begin{align*}
#     a_{n} = \frac{3}{2}\biggl(\frac{2}{3}\biggr)^{n}
# \end{align*}
#
# Now with the perturbation $a_{1}=1,a_{2}=\frac{2}{3}+\epsilon$ we need to solve
#
# \begin{align*}
#     4c_{1} + 2c_{2} &= 3 \\
#     16c_{1}+4c_{2} &= 6+9\epsilon \\
#     \Rightarrow 8c_{1} &= 9\epsilon \Rightarrow c_{2} = \frac{6-9\epsilon}{4}
# \end{align*}
#
# so now the solution is
#
# \begin{align*}
#     a_{n} = \frac{9\epsilon}{8}\biggl(\frac{4}{3}\biggr)^{n}+\frac{6-9\epsilon}{4}\biggl(\frac{2}{3}\biggr)^{n}\hspace{48pt} (\dagger)
# \end{align*}

# %% [markdown]
# ## Computational Solutions
#
# The recursion in question is calculated as follows (for 80 terms) for each of the 3 arithmetic types tested.

# %%
# Float32
Terms_32 = recursion_hom(2,-(8/9),1,2/3,80,"F32");
# Float64
Terms_64 = recursion_hom(2,-(8/9),1,2/3,80, "F64");
# BigFloat
Terms_Big = recursion_hom(BigFloat(2),-(BigFloat(8)/BigFloat(9)),BigFloat(1),BigFloat(2)/BigFloat(3),80, "Big");

# %%
# All the plotting
n = 1:1:80
semilogy(n,Terms_32, label="Float32 arithmetic", "<", markersize=ms)
title("A lin-log plot showing the recursion: "L"a_{n+1}=2a_{n}-\frac{8}{9}a_{n-1}""\n evaluated with three arithmetic types.")
xlabel("Iteration, "L"n")
ylabel(L"a_{n}"" (log scale)")

semilogy(n,Terms_64, label="Float64 arithmetic", "s", markersize=ms)

semilogy(n,Array{Float64}(Terms_Big), label="BigFloat arithmetic", "p", markersize=ms)

grid()
legend()
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x12936ea50>)

# %% [markdown]
# The results in the graph above show that using Float32 and Float64 arithmetic diverge from the exact solution quite quickly. Looking at $\dagger$ shows that with a small error $\epsilon$ the solution grows by a factor of epsilon, that is for large $n$ since $\bigl(\frac{2}{3}\bigr)^{n} \rightarrow 0$ as $n\rightarrow \infty$ $\dagger$ implies
#
# \begin{align*}
#     a_{n} = \epsilon\frac{9}{8}\biggl(\frac{4}{3}\biggr)^{n}
# \end{align*}
#
# so for large $n$ the solution grows exponentially, but consider the solution without the small perturbation
#
# \begin{align*}
# a_{n} = \frac{3}{2}\biggl(\frac{2}{3}\biggr)^{n}
# \end{align*}
#
# this clearly $\rightarrow 0$ as $n\rightarrow \infty$. The computer infact does introduce this small error due to the machine $\epsilon_{m}$, and so for large $n$ the computed value will be $\dagger$ i.e $\rightarrow \infty$.
#
# Infact the BigFloat is not immune as the machine epsilon is $O(10^{-77})$
#
#
# <font color=blue>
# You could set the precision of BigFloat even higher with the set_precision() command - the library supports arbitrary precision.
# </font>

# %%
Float64(eps(BigFloat))
# Out:
# 1.727233711018889e-77

# %%
Terms_Big300 = recursion_hom(BigFloat(2),-(BigFloat(8)/BigFloat(9)),BigFloat(1),BigFloat(2)/BigFloat(3),300, "Big");

n = 1:1:300
title("A lin-log plot showing the recursion: "L"a_{n+1}=2a_{n}-\frac{8}{9}a_{n-1}""\n with the divergence for BigFloat arithmetic")
xlabel("Iteration, "L"n")
ylabel(L"a_{n}"" (log scale)")

semilogy(n,Array{Float64}(Terms_Big300), label="BigFloat arithmetic")
grid()
legend()
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x137531e90>)

# %% [markdown]
# <font color=blue>
# Excellent answer: 15/15
# </font>

# %% [markdown]
# ## Question 2: Computational complexity of the mergesort algorithm
#
# 1. Verify that the function mergepresorted(A, B) works as described.
# 2. Write a recursive function that implements the mergesort algorithm for an array of integers whose length, $n$ is a power of 2: $n=2^m$. Verify that it works by generating some arrays of random integers and using your function to sort them.
# 3. Explain why the computational complexity, $F(n)$, of your mergesort algorithm satisfies the recursion
# > $F(n) = 2\, F(\frac{n}{2}) + n\ \ \ \ $ with initial condition $F(1)=1$.
# 4. Introduce the new variable p defined by $n = 2^p$ and let $b_p = F(2^p)$. Show that in these variables the above equation takes the form
# > $b_p = 2 b_{p−1} + 2^p\ \ \ \ $ with initial condition $b_0 = 1$.
# 5. Find the general solution to the associated homogeneous recursion relation (ie without the $2^p$ term).
# 6. Find a particular solution of the original inhomogenous recursion relation and use the initial condition to determine the constant in the homogenous solution.
# 7. Hence show that the computational complexity of the mergesort algorithm is
# > $F(n) = O(n\, \log n)$.
# 8. Use Julia's @timed macro to measure the execution time of your mergesort function for arrays of lengths $\{2^i : i =1 : 15\}$. Compare the results to the theoretical expectations.

# %% [markdown]
# ## Analytic Solutions
#
# For the computational complexity we know that the mergepresorted algorithm runs with complexity $n$ for two arrays of length $n/2,n/2$. The mergesort function is recursive and calls mergepresorted once and calls mergesort twice with arrays of size $n/2$. therefore we must have the relation
#
# \begin{align*}
#     F(n) = 2F\biggl(\frac{n}{2}\biggr)+n
# \end{align*}
#
# For the initial condition consider the case where $n=1$ then we make one comparison (if n==1) and return the array hence $F(1)=1$.
#
# Now letting $n=2^{p}, b_{p} = F(2^{p})$ we find
#
# \begin{align*}
#     F(n) = F(2^{p}) = b_{p} = 2F(2^{p}/2)+2^{p} = 2b_{p-1}+2^{p}
# \end{align*}
#
# since $F(1) = 1$ and $2^{0}=1$ we have the initial condition $b_{0}=1$.
#
# Let the homogenous problem be
#
# \begin{align*}
#     b^{H}_{p} &= 2b^{H}_{p-1}
# \end{align*}
#
# then using $\lambda^{p}=b^{H}_{p}$ we have the characteristic polynomial
#
# \begin{align*}
#     \lambda^{p} = 2\lambda^{p-1} \Rightarrow \lambda=2 \Rightarrow
#         b_{p}^{P} = Ap2^{p}+B2^{p}, \enspace A,B\in \mathbb{R}
# \end{align*}
#
# where $b_{p}^{P}$ is the particular solution of the inhomogenous problem.
#
# Using the inhomogenous problem
#
# \begin{align*}
#     Ap2^{p}+B2^{p} = 2(A(p-1)+B)2^{p-1}+2^{p} \Rightarrow Ap+B = A(p-1)+B+1 \Rightarrow A=1
# \end{align*}
#
# For $B$ we use the initial condition $b_{0}=1$
#
# \begin{align*}
#     b_{0} = 0\cdot2^{0} + B2^{0} =1 \Rightarrow B=1
# \end{align*}
#
# Using $n=2^{p} \Rightarrow p = log(n)/log(2)$ it follows
#
# \begin{align*}
#     b_{p} = 2^{p}(p+1) \Rightarrow F(n) = n(p+1) = n\biggl(\frac{log(n)}{log(2)}+1\biggr)\sim O(nlog(n))
# \end{align*}

# %%
include("modules/MSort.jl")
# contains two functions 
# mergepresorted(A::Array{Int64,1}, B::Array{Int64,1}) as given
# mergesort2(A::Array{Int64,1}) my own
# Out:
# mergesort2 (generic function with 1 method)

# %% [markdown]
# The file 'MSort.jl' contains two function with the signatures
# 'mergepresorted(A::Array{Int64,1}, B::Array{Int64,1})' as given with the question and my own function 'mergesort2(A::Array{Int64,1})'
#
# This second function takes an unsorted array. If the array has length a power of 2 length nothing is changed otherwise the function adds 0's to the array until the length is a power of 2. The function then completes the merge sort algorithm.

# %% [markdown]
# The next box shows the operation of the mergepresorted function.

# %%
A = [1,2,3,4,5,8,10,14]
B = [3,6,8,9]

C = mergepresorted(A,B)

println(C)
# Out:
# [1, 2, 3, 3, 4, 5, 6, 8, 8, 9, 10, 14]

# %% [markdown]
# Now given an unsorted array the next box shows the operation of the mergesort2 function.

# %%
A = [4,3,5,2,1,6,4,2,1];
P = mergesort2(A);

# next get rid of zeros, not in the function because there may be zeros
# in the input array. 
P=P[P.!=0]; 
println(P)
# Out:
# [1

# %%
#max power of 2
N = 15

Times = zeros(N)
Lengths = zeros(N)

for i in 1:N
    S = rand(collect(1:100),2^i)
    t = @timed mergesort2(S)
    Times[i] = t[2]
    Lengths[i] = length(t[1])
end

x = 0:1:Lengths[end]

# line through data points
#loglog(Lengths,Times)
# actual points
loglog(Lengths,Times, "x", markersize=ms, label="Observed times")

loglog(x,Times[1].*(x.*log10.(x)), label="Theoretical complexity")

title("A plot showing the theoretical and observed \n computational complexity for the merge sort algorithm above.")

xlabel("Size of array, "L"n")
ylabel("Run time, seconds")

grid()
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x122f4bb50>)
# PyObject <matplotlib.legend.Legend object at 0x12949d190>

# %% [markdown]
# <font color=blue>
# Excellent answer: 15/15
# </font>
